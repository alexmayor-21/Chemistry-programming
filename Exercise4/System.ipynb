# %%
import numpy as np
from math import exp
from decimal import Decimal

# %%
class System(object):
    
        def __init__(self, num_particles, pfun, particles=None, dim=3, init_range=50, delta=10**-5):
            self.pfun = pfun
            self.num_particles = num_particles
            self.dim = dim
            self.delta = 10**-5
            if particles:
                self.particles = particles
            else:
                self.init_range = init_range
                self.particles = [np.random.rand(self.dim) * self.init_range
                                  for num in range(num_particles)]
            self.get_potential()
            self.get_numeric_grad()          

        def get_potential(self):
            self.potential = 0.
            for ind, i in enumerate(self.particles):
                for j in self.particles[ind+1:]:
                    self.potential += self.pfun(i, j)
        
        def get_active_potential(self, particle, ignore=None):
            active_potential = 0.
            for i, neighbour in enumerate(self.particles):
                if i == ignore:
                    continue
                active_potential += self.pfun(particle, neighbour)
            return active_potential
        
        def get_numeric_grad(self):
            self.gradients = list()
            delta_matrix = np.identity(self.dim) * self.delta
            for i, particle in enumerate(self.particles):
                gradient = np.zeros(3)
                for ind in range(self.dim):
                    pot_plus = self.get_active_potential(particle + delta_matrix[ind], ignore=i)
                    pot_minus = self.get_active_potential(particle - delta_matrix[ind], ignore=i)
                    gradient[ind] = 1/(2*self.delta) * (pot_plus - pot_minus)
                self.gradients.append(gradient) 
        
        def to_XYZ(self, path):
            with open(path, 'w') as f:
                f.writeline(`self.num_particles`)
                f.writeline("Geometry of system, ")
                for i, particle in enumerate(self.particles):
                    f.writeline("Particle%i %.4f %.4f %.4f" % (i, particle[0], particle[1], particle[2]))
                
        def __str__(self):
            if self.dim != 3:
                print "Can't print for dimensions other than 3"
                return
            output = 'particle\tx\ty\tz\n'
            for i, particle in enumerate(self.particles):
                output += "%i\t\t%.3f\t%.3f\t%.3f\n" % (i+1, particle[0], particle[1], particle[2])
            return output
        
        @staticmethod
        def Lennard_Jones(sigma, epsilon):
            def Lennard_Jones_pfun(nparr1, nparr2):
                r = np.linalg.norm(nparr1 - nparr2)
                return 4*epsilon*((sigma / r)**12 - (sigma / r)**6)
            return Lennard_Jones_pfun

        @staticmethod
        def Morse(sigma, De, re):
            def Morse_pfun(nparr1, nparr2):
                r = np.linalg.norm(nparr1 = nparr2)
                return De*(1 - exp(-(r-re)/sigma))**2
            return Morse_pfun

# %%
class Optimiser(object):
        
    def __init__(self, system, lambd=1, epsilon=10**-7):
        self.system = system
        self.lambd = lambd
        self.epsilon = epsilon
        self.steps = 0
    
    def _update(self):
        self.steps += 1
        for particle, grad in zip(self.system.particles, self.system.gradients):
            particle -= self.lambd * grad
        self.system.get_numeric_grad()
        self.system.get_potential()
        
    def jump_forward(self, jump_size):
        for step in range(jump_size):
            self._update()
    
    
    def optimise(self, jump_size=10, verbose='extra'):
        jumps = 0
        diff = float("inf")
        
        while (abs(diff) > self.epsilon):
            prev_potential = self.system.potential
            self.jump_forward(jump_size)
            jumps += 1
            diff = self.system.potential - prev_potential
            if verbose == 'extra':
                if jumps % 1 == 0:
                    print 'E (%s jumps) = %.3E, change = %.3E' \
                    % (jumps, Decimal(self.system.potential), Decimal(diff))
        
        if verbose:
            print 'Converged after %i jumps (%i iterations)\n' % (jumps, jumps*jump_size)
            print(self.system)

# %%
sys = System(7, System.Lennard_Jones(1, 10))
optimiser = Optimiser(sys)
optimiser.optimise()
# Out:
# E (1 jumps) = -1.754E-04, change = -1.199E-07
# E (2 jumps) = -1.755E-04, change = -1.201E-07
# E (3 jumps) = -1.757E-04, change = -1.203E-07
# E (4 jumps) = -1.758E-04, change = -1.205E-07
# E (5 jumps) = -1.759E-04, change = -1.207E-07
# E (6 jumps) = -1.760E-04, change = -1.209E-07
# E (7 jumps) = -1.761E-04, change = -1.211E-07
# E (8 jumps) = -1.763E-04, change = -1.213E-07
# E (9 jumps) = -1.764E-04, change = -1.215E-07
# E (10 jumps) = -1.765E-04, change = -1.217E-07
# E (11 jumps) = -1.766E-04, change = -1.219E-07
# E (12 jumps) = -1.768E-04, change = -1.221E-07
# E (13 jumps) = -1.769E-04, change = -1.223E-07
# E (14 jumps) = -1.770E-04, change = -1.225E-07
# E (15 jumps) = -1.771E-04, change = -1.227E-07
# E (16 jumps) = -1.772E-04, change = -1.229E-07
# E (17 jumps) = -1.774E-04, change = -1.231E-07
# E (18 jumps) = -1.775E-04, change = -1.233E-07
# E (19 jumps) = -1.776E-04, change = -1.236E-07
# E (20 jumps) = -1.777E-04, change = -1.238E-07
# E (21 jumps) = -1.779E-04, change = -1.240E-07
# E (22 jumps) = -1.780E-04, change = -1.242E-07
# E (23 jumps) = -1.781E-04, change = -1.244E-07
# E (24 jumps) = -1.782E-04, change = -1.246E-07
# E (25 jumps) = -1.784E-04, change = -1.248E-07
# E (26 jumps) = -1.785E-04, change = -1.250E-07
# E (27 jumps) = -1.786E-04, change = -1.252E-07
# E (28 jumps) = -1.787E-04, change = -1.254E-07
# E (29 jumps) = -1.789E-04, change = -1.257E-07
# E (30 jumps) = -1.790E-04, change = -1.259E-07
# E (31 jumps) = -1.791E-04, change = -1.261E-07
# E (32 jumps) = -1.792E-04, change = -1.263E-07
# E (33 jumps) = -1.794E-04, change = -1.265E-07
# E (34 jumps) = -1.795E-04, change = -1.267E-07
# E (35 jumps) = -1.796E-04, change = -1.269E-07
# E (36 jumps) = -1.797E-04, change = -1.272E-07
# E (37 jumps) = -1.799E-04, change = -1.274E-07
# E (38 jumps) = -1.800E-04, change = -1.276E-07
# E (39 jumps) = -1.801E-04, change = -1.278E-07
# E (40 jumps) = -1.803E-04, change = -1.280E-07
# E (41 jumps) = -1.804E-04, change = -1.283E-07
# E (42 jumps) = -1.805E-04, change = -1.285E-07
# E (43 jumps) = -1.806E-04, change = -1.287E-07
# E (44 jumps) = -1.808E-04, change = -1.289E-07
# E (45 jumps) = -1.809E-04, change = -1.291E-07
# E (46 jumps) = -1.810E-04, change = -1.294E-07
# E (47 jumps) = -1.812E-04, change = -1.296E-07
# E (48 jumps) = -1.813E-04, change = -1.298E-07
# E (49 jumps) = -1.814E-04, change = -1.300E-07
# E (50 jumps) = -1.816E-04, change = -1.303E-07
# E (51 jumps) = -1.817E-04, change = -1.305E-07
# E (52 jumps) = -1.818E-04, change = -1.307E-07
# E (53 jumps) = -1.819E-04, change = -1.309E-07
# E (54 jumps) = -1.821E-04, change = -1.312E-07
# E (55 jumps) = -1.822E-04, change = -1.314E-07
# E (56 jumps) = -1.823E-04, change = -1.316E-07
# E (57 jumps) = -1.825E-04, change = -1.319E-07
# E (58 jumps) = -1.826E-04, change = -1.321E-07
# E (59 jumps) = -1.827E-04, change = -1.323E-07
# E (60 jumps) = -1.829E-04, change = -1.326E-07
# E (61 jumps) = -1.830E-04, change = -1.328E-07
# E (62 jumps) = -1.831E-04, change = -1.330E-07
# E (63 jumps) = -1.833E-04, change = -1.333E-07
# E (64 jumps) = -1.834E-04, change = -1.335E-07
# E (65 jumps) = -1.835E-04, change = -1.337E-07
# E (66 jumps) = -1.837E-04, change = -1.340E-07
# E (67 jumps) = -1.838E-04, change = -1.342E-07
# E (68 jumps) = -1.839E-04, change = -1.344E-07
# E (69 jumps) = -1.841E-04, change = -1.347E-07
# E (70 jumps) = -1.842E-04, change = -1.349E-07
# E (71 jumps) = -1.843E-04, change = -1.352E-07
# E (72 jumps) = -1.845E-04, change = -1.354E-07
# E (73 jumps) = -1.846E-04, change = -1.356E-07
# E (74 jumps) = -1.847E-04, change = -1.359E-07
# E (75 jumps) = -1.849E-04, change = -1.361E-07
# E (76 jumps) = -1.850E-04, change = -1.364E-07
# E (77 jumps) = -1.852E-04, change = -1.366E-07
# E (78 jumps) = -1.853E-04, change = -1.368E-07
# E (79 jumps) = -1.854E-04, change = -1.371E-07
# E (80 jumps) = -1.856E-04, change = -1.373E-07
# E (81 jumps) = -1.857E-04, change = -1.376E-07
# E (82 jumps) = -1.858E-04, change = -1.378E-07
# E (83 jumps) = -1.860E-04, change = -1.381E-07
# E (84 jumps) = -1.861E-04, change = -1.383E-07
# E (85 jumps) = -1.863E-04, change = -1.386E-07
# E (86 jumps) = -1.864E-04, change = -1.388E-07
# E (87 jumps) = -1.865E-04, change = -1.391E-07
# E (88 jumps) = -1.867E-04, change = -1.393E-07
# E (89 jumps) = -1.868E-04, change = -1.396E-07
# E (90 jumps) = -1.870E-04, change = -1.398E-07
# E (91 jumps) = -1.871E-04, change = -1.401E-07
# E (92 jumps) = -1.872E-04, change = -1.403E-07
# E (93 jumps) = -1.874E-04, change = -1.406E-07
# E (94 jumps) = -1.875E-04, change = -1.408E-07
# E (95 jumps) = -1.877E-04, change = -1.411E-07
# E (96 jumps) = -1.878E-04, change = -1.414E-07
# E (97 jumps) = -1.879E-04, change = -1.416E-07
# E (98 jumps) = -1.881E-04, change = -1.419E-07
# E (99 jumps) = -1.882E-04, change = -1.421E-07
# E (100 jumps) = -1.884E-04, change = -1.424E-07
# E (101 jumps) = -1.885E-04, change = -1.426E-07
# E (102 jumps) = -1.887E-04, change = -1.429E-07
# E (103 jumps) = -1.888E-04, change = -1.432E-07
# E (104 jumps) = -1.889E-04, change = -1.434E-07
# E (105 jumps) = -1.891E-04, change = -1.437E-07
# E (106 jumps) = -1.892E-04, change = -1.440E-07
# E (107 jumps) = -1.894E-04, change = -1.442E-07
# E (108 jumps) = -1.895E-04, change = -1.445E-07
# E (109 jumps) = -1.897E-04, change = -1.448E-07
# E (110 jumps) = -1.898E-04, change = -1.450E-07
# E (111 jumps) = -1.900E-04, change = -1.453E-07
# E (112 jumps) = -1.901E-04, change = -1.456E-07
# E (113 jumps) = -1.902E-04, change = -1.458E-07
# E (114 jumps) = -1.904E-04, change = -1.461E-07
# E (115 jumps) = -1.905E-04, change = -1.464E-07
# E (116 jumps) = -1.907E-04, change = -1.466E-07
# E (117 jumps) = -1.908E-04, change = -1.469E-07
# E (118 jumps) = -1.910E-04, change = -1.472E-07
# E (119 jumps) = -1.911E-04, change = -1.475E-07
# E (120 jumps) = -1.913E-04, change = -1.477E-07
# E (121 jumps) = -1.914E-04, change = -1.480E-07
# E (122 jumps) = -1.916E-04, change = -1.483E-07
# E (123 jumps) = -1.917E-04, change = -1.486E-07
# E (124 jumps) = -1.919E-04, change = -1.489E-07
# E (125 jumps) = -1.920E-04, change = -1.491E-07
# E (126 jumps) = -1.922E-04, change = -1.494E-07
# E (127 jumps) = -1.923E-04, change = -1.497E-07
# E (128 jumps) = -1.925E-04, change = -1.500E-07
# E (129 jumps) = -1.926E-04, change = -1.503E-07
# E (130 jumps) = -1.928E-04, change = -1.505E-07
# E (131 jumps) = -1.929E-04, change = -1.508E-07
# E (132 jumps) = -1.931E-04, change = -1.511E-07
# E (133 jumps) = -1.932E-04, change = -1.514E-07
# E (134 jumps) = -1.934E-04, change = -1.517E-07
# E (135 jumps) = -1.935E-04, change = -1.520E-07
# E (136 jumps) = -1.937E-04, change = -1.523E-07
# E (137 jumps) = -1.938E-04, change = -1.526E-07
# E (138 jumps) = -1.940E-04, change = -1.529E-07
# E (139 jumps) = -1.941E-04, change = -1.531E-07
# E (140 jumps) = -1.943E-04, change = -1.534E-07
# E (141 jumps) = -1.944E-04, change = -1.537E-07
# E (142 jumps) = -1.946E-04, change = -1.540E-07
# E (143 jumps) = -1.947E-04, change = -1.543E-07
# E (144 jumps) = -1.949E-04, change = -1.546E-07
# E (145 jumps) = -1.951E-04, change = -1.549E-07
# E (146 jumps) = -1.952E-04, change = -1.552E-07
# E (147 jumps) = -1.954E-04, change = -1.555E-07
# E (148 jumps) = -1.955E-04, change = -1.558E-07
# E (149 jumps) = -1.957E-04, change = -1.561E-07
# E (150 jumps) = -1.958E-04, change = -1.564E-07
# E (151 jumps) = -1.960E-04, change = -1.567E-07
# E (152 jumps) = -1.962E-04, change = -1.570E-07
# E (153 jumps) = -1.963E-04, change = -1.573E-07
# E (154 jumps) = -1.965E-04, change = -1.576E-07
# E (155 jumps) = -1.966E-04, change = -1.579E-07
# E (156 jumps) = -1.968E-04, change = -1.582E-07
# E (157 jumps) = -1.969E-04, change = -1.586E-07
# E (158 jumps) = -1.971E-04, change = -1.589E-07
# E (159 jumps) = -1.973E-04, change = -1.592E-07
# E (160 jumps) = -1.974E-04, change = -1.595E-07
# E (161 jumps) = -1.976E-04, change = -1.598E-07
# E (162 jumps) = -1.977E-04, change = -1.601E-07
# E (163 jumps) = -1.979E-04, change = -1.604E-07
# E (164 jumps) = -1.981E-04, change = -1.607E-07
# E (165 jumps) = -1.982E-04, change = -1.611E-07
# E (166 jumps) = -1.984E-04, change = -1.614E-07
# E (167 jumps) = -1.985E-04, change = -1.617E-07
# E (168 jumps) = -1.987E-04, change = -1.620E-07
# E (169 jumps) = -1.989E-04, change = -1.623E-07
# E (170 jumps) = -1.990E-04, change = -1.626E-07
# E (171 jumps) = -1.992E-04, change = -1.630E-07
# E (172 jumps) = -1.994E-04, change = -1.633E-07
# E (173 jumps) = -1.995E-04, change = -1.636E-07
# E (174 jumps) = -1.997E-04, change = -1.639E-07
# E (175 jumps) = -1.998E-04, change = -1.643E-07
# E (176 jumps) = -2.000E-04, change = -1.646E-07
# E (177 jumps) = -2.002E-04, change = -1.649E-07
# E (178 jumps) = -2.003E-04, change = -1.653E-07
# E (179 jumps) = -2.005E-04, change = -1.656E-07
# E (180 jumps) = -2.007E-04, change = -1.659E-07
# E (181 jumps) = -2.008E-04, change = -1.663E-07
# E (182 jumps) = -2.010E-04, change = -1.666E-07
# E (183 jumps) = -2.012E-04, change = -1.669E-07
# E (184 jumps) = -2.013E-04, change = -1.673E-07
# E (185 jumps) = -2.015E-04, change = -1.676E-07
# E (186 jumps) = -2.017E-04, change = -1.679E-07
# E (187 jumps) = -2.018E-04, change = -1.683E-07
# E (188 jumps) = -2.020E-04, change = -1.686E-07
# E (189 jumps) = -2.022E-04, change = -1.690E-07
# E (190 jumps) = -2.024E-04, change = -1.693E-07
# E (191 jumps) = -2.025E-04, change = -1.696E-07
# E (192 jumps) = -2.027E-04, change = -1.700E-07
# E (193 jumps) = -2.029E-04, change = -1.703E-07
# E (194 jumps) = -2.030E-04, change = -1.707E-07
# E (195 jumps) = -2.032E-04, change = -1.710E-07
# E (196 jumps) = -2.034E-04, change = -1.714E-07
# E (197 jumps) = -2.035E-04, change = -1.717E-07
# E (198 jumps) = -2.037E-04, change = -1.721E-07
# E (199 jumps) = -2.039E-04, change = -1.724E-07
# E (200 jumps) = -2.041E-04, change = -1.728E-07
# E (201 jumps) = -2.042E-04, change = -1.731E-07
# E (202 jumps) = -2.044E-04, change = -1.735E-07
# E (203 jumps) = -2.046E-04, change = -1.739E-07
# E (204 jumps) = -2.048E-04, change = -1.742E-07
# E (205 jumps) = -2.049E-04, change = -1.746E-07
# E (206 jumps) = -2.051E-04, change = -1.749E-07
# E (207 jumps) = -2.053E-04, change = -1.753E-07
# E (208 jumps) = -2.055E-04, change = -1.757E-07
# E (209 jumps) = -2.056E-04, change = -1.760E-07
# E (210 jumps) = -2.058E-04, change = -1.764E-07
# E (211 jumps) = -2.060E-04, change = -1.768E-07
# E (212 jumps) = -2.062E-04, change = -1.771E-07
# E (213 jumps) = -2.063E-04, change = -1.775E-07
# E (214 jumps) = -2.065E-04, change = -1.779E-07
# E (215 jumps) = -2.067E-04, change = -1.782E-07
# E (216 jumps) = -2.069E-04, change = -1.786E-07
# E (217 jumps) = -2.071E-04, change = -1.790E-07
# E (218 jumps) = -2.072E-04, change = -1.794E-07
# E (219 jumps) = -2.074E-04, change = -1.797E-07
# E (220 jumps) = -2.076E-04, change = -1.801E-07
# E (221 jumps) = -2.078E-04, change = -1.805E-07
# E (222 jumps) = -2.080E-04, change = -1.809E-07
# E (223 jumps) = -2.081E-04, change = -1.813E-07
# E (224 jumps) = -2.083E-04, change = -1.816E-07
# E (225 jumps) = -2.085E-04, change = -1.820E-07
# E (226 jumps) = -2.087E-04, change = -1.824E-07
# E (227 jumps) = -2.089E-04, change = -1.828E-07
# E (228 jumps) = -2.091E-04, change = -1.832E-07
# E (229 jumps) = -2.092E-04, change = -1.836E-07
# E (230 jumps) = -2.094E-04, change = -1.840E-07
# E (231 jumps) = -2.096E-04, change = -1.844E-07
# E (232 jumps) = -2.098E-04, change = -1.848E-07
# E (233 jumps) = -2.100E-04, change = -1.852E-07
# E (234 jumps) = -2.102E-04, change = -1.856E-07
# E (235 jumps) = -2.103E-04, change = -1.860E-07
# E (236 jumps) = -2.105E-04, change = -1.864E-07
# E (237 jumps) = -2.107E-04, change = -1.868E-07
# E (238 jumps) = -2.109E-04, change = -1.872E-07
# E (239 jumps) = -2.111E-04, change = -1.876E-07
# E (240 jumps) = -2.113E-04, change = -1.880E-07
# E (241 jumps) = -2.115E-04, change = -1.884E-07
# E (242 jumps) = -2.117E-04, change = -1.888E-07
# E (243 jumps) = -2.118E-04, change = -1.892E-07
# E (244 jumps) = -2.120E-04, change = -1.896E-07
# E (245 jumps) = -2.122E-04, change = -1.900E-07
# E (246 jumps) = -2.124E-04, change = -1.904E-07
# E (247 jumps) = -2.126E-04, change = -1.908E-07
# E (248 jumps) = -2.128E-04, change = -1.913E-07
# E (249 jumps) = -2.130E-04, change = -1.917E-07
# E (250 jumps) = -2.132E-04, change = -1.921E-07
# E (251 jumps) = -2.134E-04, change = -1.925E-07
# E (252 jumps) = -2.136E-04, change = -1.929E-07
# E (253 jumps) = -2.138E-04, change = -1.934E-07
# E (254 jumps) = -2.140E-04, change = -1.938E-07
# E (255 jumps) = -2.141E-04, change = -1.942E-07
# E (256 jumps) = -2.143E-04, change = -1.946E-07
# E (257 jumps) = -2.145E-04, change = -1.951E-07
# E (258 jumps) = -2.147E-04, change = -1.955E-07
# E (259 jumps) = -2.149E-04, change = -1.959E-07
# E (260 jumps) = -2.151E-04, change = -1.964E-07
# E (261 jumps) = -2.153E-04, change = -1.968E-07
# E (262 jumps) = -2.155E-04, change = -1.973E-07
# E (263 jumps) = -2.157E-04, change = -1.977E-07
# E (264 jumps) = -2.159E-04, change = -1.981E-07
# E (265 jumps) = -2.161E-04, change = -1.986E-07
# E (266 jumps) = -2.163E-04, change = -1.990E-07
# E (267 jumps) = -2.165E-04, change = -1.995E-07
# E (268 jumps) = -2.167E-04, change = -1.999E-07
# E (269 jumps) = -2.169E-04, change = -2.004E-07
# E (270 jumps) = -2.171E-04, change = -2.008E-07
# E (271 jumps) = -2.173E-04, change = -2.013E-07
# E (272 jumps) = -2.175E-04, change = -2.017E-07
# E (273 jumps) = -2.177E-04, change = -2.022E-07
# E (274 jumps) = -2.179E-04, change = -2.026E-07
# E (275 jumps) = -2.181E-04, change = -2.031E-07
# E (276 jumps) = -2.183E-04, change = -2.036E-07
# E (277 jumps) = -2.185E-04, change = -2.040E-07
# E (278 jumps) = -2.187E-04, change = -2.045E-07
# E (279 jumps) = -2.189E-04, change = -2.049E-07
# E (280 jumps) = -2.191E-04, change = -2.054E-07
# E (281 jumps) = -2.194E-04, change = -2.059E-07
# E (282 jumps) = -2.196E-04, change = -2.064E-07
# E (283 jumps) = -2.198E-04, change = -2.068E-07
# E (284 jumps) = -2.200E-04, change = -2.073E-07
# E (285 jumps) = -2.202E-04, change = -2.078E-07
# E (286 jumps) = -2.204E-04, change = -2.083E-07
# E (287 jumps) = -2.206E-04, change = -2.087E-07
# E (288 jumps) = -2.208E-04, change = -2.092E-07
# E (289 jumps) = -2.210E-04, change = -2.097E-07
# E (290 jumps) = -2.212E-04, change = -2.102E-07
# E (291 jumps) = -2.214E-04, change = -2.107E-07
# E (292 jumps) = -2.216E-04, change = -2.112E-07
# E (293 jumps) = -2.219E-04, change = -2.117E-07
# E (294 jumps) = -2.221E-04, change = -2.122E-07
# E (295 jumps) = -2.223E-04, change = -2.126E-07
# E (296 jumps) = -2.225E-04, change = -2.131E-07
# E (297 jumps) = -2.227E-04, change = -2.136E-07
# E (298 jumps) = -2.229E-04, change = -2.141E-07
# E (299 jumps) = -2.231E-04, change = -2.146E-07
# E (300 jumps) = -2.234E-04, change = -2.151E-07
# E (301 jumps) = -2.236E-04, change = -2.157E-07
# E (302 jumps) = -2.238E-04, change = -2.162E-07
# E (303 jumps) = -2.240E-04, change = -2.167E-07
# E (304 jumps) = -2.242E-04, change = -2.172E-07
# E (305 jumps) = -2.244E-04, change = -2.177E-07
# E (306 jumps) = -2.247E-04, change = -2.182E-07
# E (307 jumps) = -2.249E-04, change = -2.187E-07
# E (308 jumps) = -2.251E-04, change = -2.193E-07
# E (309 jumps) = -2.253E-04, change = -2.198E-07
# E (310 jumps) = -2.255E-04, change = -2.203E-07
# E (311 jumps) = -2.258E-04, change = -2.208E-07
# E (312 jumps) = -2.260E-04, change = -2.214E-07
# E (313 jumps) = -2.262E-04, change = -2.219E-07
# E (314 jumps) = -2.264E-04, change = -2.224E-07
# E (315 jumps) = -2.266E-04, change = -2.229E-07
# E (316 jumps) = -2.269E-04, change = -2.235E-07
# E (317 jumps) = -2.271E-04, change = -2.240E-07
# E (318 jumps) = -2.273E-04, change = -2.246E-07
# E (319 jumps) = -2.275E-04, change = -2.251E-07
# E (320 jumps) = -2.278E-04, change = -2.257E-07
# E (321 jumps) = -2.280E-04, change = -2.262E-07
# E (322 jumps) = -2.282E-04, change = -2.267E-07
# E (323 jumps) = -2.284E-04, change = -2.273E-07
# E (324 jumps) = -2.287E-04, change = -2.279E-07
# E (325 jumps) = -2.289E-04, change = -2.284E-07
# E (326 jumps) = -2.291E-04, change = -2.290E-07
# E (327 jumps) = -2.294E-04, change = -2.295E-07
# E (328 jumps) = -2.296E-04, change = -2.301E-07
# E (329 jumps) = -2.298E-04, change = -2.307E-07
# E (330 jumps) = -2.301E-04, change = -2.312E-07
# E (331 jumps) = -2.303E-04, change = -2.318E-07
# E (332 jumps) = -2.305E-04, change = -2.324E-07
# E (333 jumps) = -2.308E-04, change = -2.329E-07
# E (334 jumps) = -2.310E-04, change = -2.335E-07
# E (335 jumps) = -2.312E-04, change = -2.341E-07
# E (336 jumps) = -2.315E-04, change = -2.347E-07
# E (337 jumps) = -2.317E-04, change = -2.353E-07
# E (338 jumps) = -2.319E-04, change = -2.358E-07
# E (339 jumps) = -2.322E-04, change = -2.364E-07
# E (340 jumps) = -2.324E-04, change = -2.370E-07
# E (341 jumps) = -2.326E-04, change = -2.376E-07
# E (342 jumps) = -2.329E-04, change = -2.382E-07
# E (343 jumps) = -2.331E-04, change = -2.388E-07
# E (344 jumps) = -2.334E-04, change = -2.394E-07
# E (345 jumps) = -2.336E-04, change = -2.400E-07
# E (346 jumps) = -2.338E-04, change = -2.406E-07
# E (347 jumps) = -2.341E-04, change = -2.412E-07
# E (348 jumps) = -2.343E-04, change = -2.418E-07
# E (349 jumps) = -2.346E-04, change = -2.424E-07
# E (350 jumps) = -2.348E-04, change = -2.431E-07
# E (351 jumps) = -2.350E-04, change = -2.437E-07
# E (352 jumps) = -2.353E-04, change = -2.443E-07
# E (353 jumps) = -2.355E-04, change = -2.449E-07
# E (354 jumps) = -2.358E-04, change = -2.455E-07
# E (355 jumps) = -2.360E-04, change = -2.462E-07
# E (356 jumps) = -2.363E-04, change = -2.468E-07
# E (357 jumps) = -2.365E-04, change = -2.474E-07
# E (358 jumps) = -2.368E-04, change = -2.481E-07
# E (359 jumps) = -2.370E-04, change = -2.487E-07
# E (360 jumps) = -2.373E-04, change = -2.493E-07
# E (361 jumps) = -2.375E-04, change = -2.500E-07
# E (362 jumps) = -2.378E-04, change = -2.506E-07
# E (363 jumps) = -2.380E-04, change = -2.513E-07
# E (364 jumps) = -2.383E-04, change = -2.519E-07
# E (365 jumps) = -2.385E-04, change = -2.526E-07
# E (366 jumps) = -2.388E-04, change = -2.532E-07
# E (367 jumps) = -2.390E-04, change = -2.539E-07
# E (368 jumps) = -2.393E-04, change = -2.546E-07
# E (369 jumps) = -2.395E-04, change = -2.552E-07
# E (370 jumps) = -2.398E-04, change = -2.559E-07
# E (371 jumps) = -2.401E-04, change = -2.566E-07
# E (372 jumps) = -2.403E-04, change = -2.573E-07
# E (373 jumps) = -2.406E-04, change = -2.579E-07
# E (374 jumps) = -2.408E-04, change = -2.586E-07
# E (375 jumps) = -2.411E-04, change = -2.593E-07
# E (376 jumps) = -2.413E-04, change = -2.600E-07
# E (377 jumps) = -2.416E-04, change = -2.607E-07
# E (378 jumps) = -2.419E-04, change = -2.614E-07
# E (379 jumps) = -2.421E-04, change = -2.621E-07
# E (380 jumps) = -2.424E-04, change = -2.628E-07
# E (381 jumps) = -2.427E-04, change = -2.635E-07
# E (382 jumps) = -2.429E-04, change = -2.642E-07
# E (383 jumps) = -2.432E-04, change = -2.649E-07
# E (384 jumps) = -2.435E-04, change = -2.656E-07
# E (385 jumps) = -2.437E-04, change = -2.663E-07
# E (386 jumps) = -2.440E-04, change = -2.670E-07
# E (387 jumps) = -2.443E-04, change = -2.677E-07
# E (388 jumps) = -2.445E-04, change = -2.685E-07
# E (389 jumps) = -2.448E-04, change = -2.692E-07
# E (390 jumps) = -2.451E-04, change = -2.699E-07
# E (391 jumps) = -2.453E-04, change = -2.706E-07
# E (392 jumps) = -2.456E-04, change = -2.714E-07
# E (393 jumps) = -2.459E-04, change = -2.721E-07
# E (394 jumps) = -2.461E-04, change = -2.729E-07
# E (395 jumps) = -2.464E-04, change = -2.736E-07
# E (396 jumps) = -2.467E-04, change = -2.744E-07
# E (397 jumps) = -2.470E-04, change = -2.751E-07
# E (398 jumps) = -2.472E-04, change = -2.759E-07
# E (399 jumps) = -2.475E-04, change = -2.766E-07
# E (400 jumps) = -2.478E-04, change = -2.774E-07
# E (401 jumps) = -2.481E-04, change = -2.782E-07
# E (402 jumps) = -2.484E-04, change = -2.789E-07
# E (403 jumps) = -2.486E-04, change = -2.797E-07
# E (404 jumps) = -2.489E-04, change = -2.805E-07
# E (405 jumps) = -2.492E-04, change = -2.813E-07
# E (406 jumps) = -2.495E-04, change = -2.821E-07
# E (407 jumps) = -2.498E-04, change = -2.828E-07
# E (408 jumps) = -2.500E-04, change = -2.836E-07
# E (409 jumps) = -2.503E-04, change = -2.844E-07
# E (410 jumps) = -2.506E-04, change = -2.852E-07
# E (411 jumps) = -2.509E-04, change = -2.860E-07
# E (412 jumps) = -2.512E-04, change = -2.868E-07
# E (413 jumps) = -2.515E-04, change = -2.876E-07
# E (414 jumps) = -2.518E-04, change = -2.885E-07
# E (415 jumps) = -2.521E-04, change = -2.893E-07
# E (416 jumps) = -2.523E-04, change = -2.901E-07
# E (417 jumps) = -2.526E-04, change = -2.909E-07
# E (418 jumps) = -2.529E-04, change = -2.918E-07
# E (419 jumps) = -2.532E-04, change = -2.926E-07
# E (420 jumps) = -2.535E-04, change = -2.934E-07
# E (421 jumps) = -2.538E-04, change = -2.943E-07
# E (422 jumps) = -2.541E-04, change = -2.951E-07
# E (423 jumps) = -2.544E-04, change = -2.960E-07
# E (424 jumps) = -2.547E-04, change = -2.968E-07
# E (425 jumps) = -2.550E-04, change = -2.977E-07
# E (426 jumps) = -2.553E-04, change = -2.985E-07
# E (427 jumps) = -2.556E-04, change = -2.994E-07
# E (428 jumps) = -2.559E-04, change = -3.003E-07
# E (429 jumps) = -2.562E-04, change = -3.011E-07
# E (430 jumps) = -2.565E-04, change = -3.020E-07
# E (431 jumps) = -2.568E-04, change = -3.029E-07
# E (432 jumps) = -2.571E-04, change = -3.038E-07
# E (433 jumps) = -2.574E-04, change = -3.047E-07
# E (434 jumps) = -2.577E-04, change = -3.056E-07
# E (435 jumps) = -2.580E-04, change = -3.065E-07
# E (436 jumps) = -2.583E-04, change = -3.074E-07
# E (437 jumps) = -2.586E-04, change = -3.083E-07
# E (438 jumps) = -2.589E-04, change = -3.092E-07
# E (439 jumps) = -2.593E-04, change = -3.101E-07
# E (440 jumps) = -2.596E-04, change = -3.110E-07
# E (441 jumps) = -2.599E-04, change = -3.120E-07
# E (442 jumps) = -2.602E-04, change = -3.129E-07
# E (443 jumps) = -2.605E-04, change = -3.138E-07
# E (444 jumps) = -2.608E-04, change = -3.148E-07
# E (445 jumps) = -2.611E-04, change = -3.157E-07
# E (446 jumps) = -2.615E-04, change = -3.167E-07
# E (447 jumps) = -2.618E-04, change = -3.176E-07
# E (448 jumps) = -2.621E-04, change = -3.186E-07
# E (449 jumps) = -2.624E-04, change = -3.196E-07
# E (450 jumps) = -2.627E-04, change = -3.205E-07
# E (451 jumps) = -2.630E-04, change = -3.215E-07
# E (452 jumps) = -2.634E-04, change = -3.225E-07
# E (453 jumps) = -2.637E-04, change = -3.235E-07
# E (454 jumps) = -2.640E-04, change = -3.244E-07
# E (455 jumps) = -2.643E-04, change = -3.254E-07
# E (456 jumps) = -2.647E-04, change = -3.264E-07
# E (457 jumps) = -2.650E-04, change = -3.274E-07
# E (458 jumps) = -2.653E-04, change = -3.285E-07
# E (459 jumps) = -2.657E-04, change = -3.295E-07
# E (460 jumps) = -2.660E-04, change = -3.305E-07
# E (461 jumps) = -2.663E-04, change = -3.315E-07
# E (462 jumps) = -2.667E-04, change = -3.325E-07
# E (463 jumps) = -2.670E-04, change = -3.336E-07
# E (464 jumps) = -2.673E-04, change = -3.346E-07
# E (465 jumps) = -2.677E-04, change = -3.357E-07
# E (466 jumps) = -2.680E-04, change = -3.367E-07
# E (467 jumps) = -2.683E-04, change = -3.378E-07
# E (468 jumps) = -2.687E-04, change = -3.388E-07
# E (469 jumps) = -2.690E-04, change = -3.399E-07
# E (470 jumps) = -2.693E-04, change = -3.410E-07
# E (471 jumps) = -2.697E-04, change = -3.421E-07
# E (472 jumps) = -2.700E-04, change = -3.431E-07
# E (473 jumps) = -2.704E-04, change = -3.442E-07
# E (474 jumps) = -2.707E-04, change = -3.453E-07
# E (475 jumps) = -2.711E-04, change = -3.464E-07
# E (476 jumps) = -2.714E-04, change = -3.475E-07
# E (477 jumps) = -2.718E-04, change = -3.487E-07
# E (478 jumps) = -2.721E-04, change = -3.498E-07
# E (479 jumps) = -2.725E-04, change = -3.509E-07
# E (480 jumps) = -2.728E-04, change = -3.520E-07
# E (481 jumps) = -2.732E-04, change = -3.532E-07
# E (482 jumps) = -2.735E-04, change = -3.543E-07
# E (483 jumps) = -2.739E-04, change = -3.555E-07
# E (484 jumps) = -2.742E-04, change = -3.566E-07
# E (485 jumps) = -2.746E-04, change = -3.578E-07
# E (486 jumps) = -2.750E-04, change = -3.590E-07
# E (487 jumps) = -2.753E-04, change = -3.601E-07
# E (488 jumps) = -2.757E-04, change = -3.613E-07
# E (489 jumps) = -2.760E-04, change = -3.625E-07
# E (490 jumps) = -2.764E-04, change = -3.637E-07
# E (491 jumps) = -2.768E-04, change = -3.649E-07
# E (492 jumps) = -2.771E-04, change = -3.661E-07
# E (493 jumps) = -2.775E-04, change = -3.673E-07
# E (494 jumps) = -2.779E-04, change = -3.685E-07
# E (495 jumps) = -2.782E-04, change = -3.698E-07
# E (496 jumps) = -2.786E-04, change = -3.710E-07
# E (497 jumps) = -2.790E-04, change = -3.723E-07
# E (498 jumps) = -2.794E-04, change = -3.735E-07
# E (499 jumps) = -2.797E-04, change = -3.748E-07
# E (500 jumps) = -2.801E-04, change = -3.760E-07
# E (501 jumps) = -2.805E-04, change = -3.773E-07
# E (502 jumps) = -2.809E-04, change = -3.786E-07
# E (503 jumps) = -2.812E-04, change = -3.799E-07
# E (504 jumps) = -2.816E-04, change = -3.812E-07
# E (505 jumps) = -2.820E-04, change = -3.825E-07
# E (506 jumps) = -2.824E-04, change = -3.838E-07
# E (507 jumps) = -2.828E-04, change = -3.851E-07
# E (508 jumps) = -2.832E-04, change = -3.864E-07
# E (509 jumps) = -2.835E-04, change = -3.877E-07
# E (510 jumps) = -2.839E-04, change = -3.891E-07
# E (511 jumps) = -2.843E-04, change = -3.904E-07
# E (512 jumps) = -2.847E-04, change = -3.918E-07
# E (513 jumps) = -2.851E-04, change = -3.931E-07
# E (514 jumps) = -2.855E-04, change = -3.945E-07
# E (515 jumps) = -2.859E-04, change = -3.959E-07
# E (516 jumps) = -2.863E-04, change = -3.973E-07
# E (517 jumps) = -2.867E-04, change = -3.987E-07
# E (518 jumps) = -2.871E-04, change = -4.001E-07
# E (519 jumps) = -2.875E-04, change = -4.015E-07
# E (520 jumps) = -2.879E-04, change = -4.029E-07
# E (521 jumps) = -2.883E-04, change = -4.043E-07
# E (522 jumps) = -2.887E-04, change = -4.058E-07
# E (523 jumps) = -2.891E-04, change = -4.072E-07
# E (524 jumps) = -2.895E-04, change = -4.087E-07
# E (525 jumps) = -2.899E-04, change = -4.101E-07
# E (526 jumps) = -2.904E-04, change = -4.116E-07
# E (527 jumps) = -2.908E-04, change = -4.131E-07
# E (528 jumps) = -2.912E-04, change = -4.146E-07
# E (529 jumps) = -2.916E-04, change = -4.161E-07
# E (530 jumps) = -2.920E-04, change = -4.176E-07
# E (531 jumps) = -2.924E-04, change = -4.191E-07
# E (532 jumps) = -2.929E-04, change = -4.206E-07
# E (533 jumps) = -2.933E-04, change = -4.221E-07
# E (534 jumps) = -2.937E-04, change = -4.237E-07
# E (535 jumps) = -2.941E-04, change = -4.252E-07
# E (536 jumps) = -2.946E-04, change = -4.268E-07
# E (537 jumps) = -2.950E-04, change = -4.284E-07
# E (538 jumps) = -2.954E-04, change = -4.300E-07
# E (539 jumps) = -2.958E-04, change = -4.315E-07
# E (540 jumps) = -2.963E-04, change = -4.331E-07
# E (541 jumps) = -2.967E-04, change = -4.348E-07
# E (542 jumps) = -2.971E-04, change = -4.364E-07
# E (543 jumps) = -2.976E-04, change = -4.380E-07
# E (544 jumps) = -2.980E-04, change = -4.397E-07
# E (545 jumps) = -2.985E-04, change = -4.413E-07
# E (546 jumps) = -2.989E-04, change = -4.430E-07
# E (547 jumps) = -2.994E-04, change = -4.447E-07
# E (548 jumps) = -2.998E-04, change = -4.463E-07
# E (549 jumps) = -3.002E-04, change = -4.480E-07
# E (550 jumps) = -3.007E-04, change = -4.497E-07
# E (551 jumps) = -3.011E-04, change = -4.515E-07
# E (552 jumps) = -3.016E-04, change = -4.532E-07
# E (553 jumps) = -3.021E-04, change = -4.549E-07
# E (554 jumps) = -3.025E-04, change = -4.567E-07
# E (555 jumps) = -3.030E-04, change = -4.584E-07
# E (556 jumps) = -3.034E-04, change = -4.602E-07
# E (557 jumps) = -3.039E-04, change = -4.620E-07
# E (558 jumps) = -3.044E-04, change = -4.638E-07
# E (559 jumps) = -3.048E-04, change = -4.656E-07
# E (560 jumps) = -3.053E-04, change = -4.674E-07
# E (561 jumps) = -3.058E-04, change = -4.693E-07
# E (562 jumps) = -3.062E-04, change = -4.711E-07
# E (563 jumps) = -3.067E-04, change = -4.730E-07
# E (564 jumps) = -3.072E-04, change = -4.749E-07
# E (565 jumps) = -3.077E-04, change = -4.767E-07
# E (566 jumps) = -3.081E-04, change = -4.786E-07
# E (567 jumps) = -3.086E-04, change = -4.805E-07
# E (568 jumps) = -3.091E-04, change = -4.825E-07
# E (569 jumps) = -3.096E-04, change = -4.844E-07
# E (570 jumps) = -3.101E-04, change = -4.864E-07
# E (571 jumps) = -3.106E-04, change = -4.883E-07
# E (572 jumps) = -3.110E-04, change = -4.903E-07
# E (573 jumps) = -3.115E-04, change = -4.923E-07
# E (574 jumps) = -3.120E-04, change = -4.943E-07
# E (575 jumps) = -3.125E-04, change = -4.963E-07
# E (576 jumps) = -3.130E-04, change = -4.983E-07
# E (577 jumps) = -3.135E-04, change = -5.004E-07
# E (578 jumps) = -3.140E-04, change = -5.024E-07
# E (579 jumps) = -3.145E-04, change = -5.045E-07
# E (580 jumps) = -3.150E-04, change = -5.066E-07
# E (581 jumps) = -3.155E-04, change = -5.087E-07
# E (582 jumps) = -3.161E-04, change = -5.108E-07
# E (583 jumps) = -3.166E-04, change = -5.130E-07
# E (584 jumps) = -3.171E-04, change = -5.151E-07
# E (585 jumps) = -3.176E-04, change = -5.173E-07
# E (586 jumps) = -3.181E-04, change = -5.194E-07
# E (587 jumps) = -3.186E-04, change = -5.216E-07
# E (588 jumps) = -3.192E-04, change = -5.239E-07
# E (589 jumps) = -3.197E-04, change = -5.261E-07
# E (590 jumps) = -3.202E-04, change = -5.283E-07
# E (591 jumps) = -3.208E-04, change = -5.306E-07
# E (592 jumps) = -3.213E-04, change = -5.329E-07
# E (593 jumps) = -3.218E-04, change = -5.352E-07
# E (594 jumps) = -3.224E-04, change = -5.375E-07
# E (595 jumps) = -3.229E-04, change = -5.398E-07
# E (596 jumps) = -3.234E-04, change = -5.421E-07
# E (597 jumps) = -3.240E-04, change = -5.445E-07
# E (598 jumps) = -3.245E-04, change = -5.469E-07
# E (599 jumps) = -3.251E-04, change = -5.493E-07
# E (600 jumps) = -3.256E-04, change = -5.517E-07
# E (601 jumps) = -3.262E-04, change = -5.541E-07
# E (602 jumps) = -3.267E-04, change = -5.566E-07
# E (603 jumps) = -3.273E-04, change = -5.590E-07
# E (604 jumps) = -3.279E-04, change = -5.615E-07
# E (605 jumps) = -3.284E-04, change = -5.640E-07
# E (606 jumps) = -3.290E-04, change = -5.666E-07
# E (607 jumps) = -3.296E-04, change = -5.691E-07
# E (608 jumps) = -3.301E-04, change = -5.717E-07
# E (609 jumps) = -3.307E-04, change = -5.743E-07
# E (610 jumps) = -3.313E-04, change = -5.769E-07
# E (611 jumps) = -3.319E-04, change = -5.795E-07
# E (612 jumps) = -3.325E-04, change = -5.821E-07
# E (613 jumps) = -3.330E-04, change = -5.848E-07
# E (614 jumps) = -3.336E-04, change = -5.875E-07
# E (615 jumps) = -3.342E-04, change = -5.902E-07
# E (616 jumps) = -3.348E-04, change = -5.929E-07
# E (617 jumps) = -3.354E-04, change = -5.957E-07
# E (618 jumps) = -3.360E-04, change = -5.985E-07
# E (619 jumps) = -3.366E-04, change = -6.013E-07
# E (620 jumps) = -3.372E-04, change = -6.041E-07
# E (621 jumps) = -3.378E-04, change = -6.069E-07
# E (622 jumps) = -3.384E-04, change = -6.098E-07
# E (623 jumps) = -3.390E-04, change = -6.127E-07
# E (624 jumps) = -3.397E-04, change = -6.156E-07
# E (625 jumps) = -3.403E-04, change = -6.185E-07
# E (626 jumps) = -3.409E-04, change = -6.215E-07
# E (627 jumps) = -3.415E-04, change = -6.245E-07
# E (628 jumps) = -3.421E-04, change = -6.275E-07
# E (629 jumps) = -3.428E-04, change = -6.305E-07
# E (630 jumps) = -3.434E-04, change = -6.336E-07
# E (631 jumps) = -3.440E-04, change = -6.366E-07
# E (632 jumps) = -3.447E-04, change = -6.398E-07
# E (633 jumps) = -3.453E-04, change = -6.429E-07
# E (634 jumps) = -3.460E-04, change = -6.461E-07
# E (635 jumps) = -3.466E-04, change = -6.492E-07
# E (636 jumps) = -3.473E-04, change = -6.525E-07
# E (637 jumps) = -3.479E-04, change = -6.557E-07
# E (638 jumps) = -3.486E-04, change = -6.590E-07
# E (639 jumps) = -3.493E-04, change = -6.623E-07
# E (640 jumps) = -3.499E-04, change = -6.656E-07
# E (641 jumps) = -3.506E-04, change = -6.690E-07
# E (642 jumps) = -3.513E-04, change = -6.724E-07
# E (643 jumps) = -3.519E-04, change = -6.758E-07
# E (644 jumps) = -3.526E-04, change = -6.792E-07
# E (645 jumps) = -3.533E-04, change = -6.827E-07
# E (646 jumps) = -3.540E-04, change = -6.862E-07
# E (647 jumps) = -3.547E-04, change = -6.897E-07
# E (648 jumps) = -3.554E-04, change = -6.933E-07
# E (649 jumps) = -3.561E-04, change = -6.969E-07
# E (650 jumps) = -3.568E-04, change = -7.005E-07
# E (651 jumps) = -3.575E-04, change = -7.042E-07
# E (652 jumps) = -3.582E-04, change = -7.079E-07
# E (653 jumps) = -3.589E-04, change = -7.116E-07
# E (654 jumps) = -3.596E-04, change = -7.154E-07
# E (655 jumps) = -3.603E-04, change = -7.192E-07
# E (656 jumps) = -3.610E-04, change = -7.231E-07
# E (657 jumps) = -3.618E-04, change = -7.269E-07
# E (658 jumps) = -3.625E-04, change = -7.308E-07
# E (659 jumps) = -3.632E-04, change = -7.348E-07
# E (660 jumps) = -3.640E-04, change = -7.388E-07
# E (661 jumps) = -3.647E-04, change = -7.428E-07
# E (662 jumps) = -3.655E-04, change = -7.468E-07
# E (663 jumps) = -3.662E-04, change = -7.509E-07
# E (664 jumps) = -3.670E-04, change = -7.551E-07
# E (665 jumps) = -3.677E-04, change = -7.592E-07
# E (666 jumps) = -3.685E-04, change = -7.634E-07
# E (667 jumps) = -3.693E-04, change = -7.677E-07
# E (668 jumps) = -3.700E-04, change = -7.720E-07
# E (669 jumps) = -3.708E-04, change = -7.763E-07
# E (670 jumps) = -3.716E-04, change = -7.807E-07
# E (671 jumps) = -3.724E-04, change = -7.851E-07
# E (672 jumps) = -3.732E-04, change = -7.896E-07
# E (673 jumps) = -3.740E-04, change = -7.941E-07
# E (674 jumps) = -3.748E-04, change = -7.987E-07
# E (675 jumps) = -3.756E-04, change = -8.033E-07
# E (676 jumps) = -3.764E-04, change = -8.079E-07
# E (677 jumps) = -3.772E-04, change = -8.126E-07
# E (678 jumps) = -3.780E-04, change = -8.173E-07
# E (679 jumps) = -3.788E-04, change = -8.221E-07
# E (680 jumps) = -3.796E-04, change = -8.270E-07
# E (681 jumps) = -3.805E-04, change = -8.318E-07
# E (682 jumps) = -3.813E-04, change = -8.368E-07
# E (683 jumps) = -3.822E-04, change = -8.418E-07
# E (684 jumps) = -3.830E-04, change = -8.468E-07
# E (685 jumps) = -3.839E-04, change = -8.519E-07
# E (686 jumps) = -3.847E-04, change = -8.570E-07
# E (687 jumps) = -3.856E-04, change = -8.622E-07
# E (688 jumps) = -3.864E-04, change = -8.675E-07
# E (689 jumps) = -3.873E-04, change = -8.728E-07
# E (690 jumps) = -3.882E-04, change = -8.781E-07
# E (691 jumps) = -3.891E-04, change = -8.835E-07
# E (692 jumps) = -3.900E-04, change = -8.890E-07
# E (693 jumps) = -3.909E-04, change = -8.946E-07
# E (694 jumps) = -3.918E-04, change = -9.002E-07
# E (695 jumps) = -3.927E-04, change = -9.058E-07
# E (696 jumps) = -3.936E-04, change = -9.115E-07
# E (697 jumps) = -3.945E-04, change = -9.173E-07
# E (698 jumps) = -3.954E-04, change = -9.232E-07
# E (699 jumps) = -3.963E-04, change = -9.291E-07
# E (700 jumps) = -3.973E-04, change = -9.350E-07
# E (701 jumps) = -3.982E-04, change = -9.411E-07
# E (702 jumps) = -3.992E-04, change = -9.472E-07
# E (703 jumps) = -4.001E-04, change = -9.534E-07
# E (704 jumps) = -4.011E-04, change = -9.596E-07
# E (705 jumps) = -4.021E-04, change = -9.659E-07
# E (706 jumps) = -4.030E-04, change = -9.723E-07
# E (707 jumps) = -4.040E-04, change = -9.788E-07
# E (708 jumps) = -4.050E-04, change = -9.853E-07
# E (709 jumps) = -4.060E-04, change = -9.919E-07
# E (710 jumps) = -4.070E-04, change = -9.986E-07
# E (711 jumps) = -4.080E-04, change = -1.005E-06
# E (712 jumps) = -4.090E-04, change = -1.012E-06
# E (713 jumps) = -4.100E-04, change = -1.019E-06
# E (714 jumps) = -4.110E-04, change = -1.026E-06
# E (715 jumps) = -4.121E-04, change = -1.033E-06
# E (716 jumps) = -4.131E-04, change = -1.040E-06
# E (717 jumps) = -4.142E-04, change = -1.048E-06
# E (718 jumps) = -4.152E-04, change = -1.055E-06
# E (719 jumps) = -4.163E-04, change = -1.063E-06
# E (720 jumps) = -4.173E-04, change = -1.070E-06
# E (721 jumps) = -4.184E-04, change = -1.078E-06
# E (722 jumps) = -4.195E-04, change = -1.085E-06
# E (723 jumps) = -4.206E-04, change = -1.093E-06
# E (724 jumps) = -4.217E-04, change = -1.101E-06
# E (725 jumps) = -4.228E-04, change = -1.109E-06
# E (726 jumps) = -4.239E-04, change = -1.117E-06
# E (727 jumps) = -4.251E-04, change = -1.126E-06
# E (728 jumps) = -4.262E-04, change = -1.134E-06
# E (729 jumps) = -4.273E-04, change = -1.142E-06
# E (730 jumps) = -4.285E-04, change = -1.151E-06
# E (731 jumps) = -4.296E-04, change = -1.160E-06
# E (732 jumps) = -4.308E-04, change = -1.168E-06
# E (733 jumps) = -4.320E-04, change = -1.177E-06
# E (734 jumps) = -4.332E-04, change = -1.186E-06
# E (735 jumps) = -4.344E-04, change = -1.195E-06
# E (736 jumps) = -4.356E-04, change = -1.205E-06
# E (737 jumps) = -4.368E-04, change = -1.214E-06
# E (738 jumps) = -4.380E-04, change = -1.223E-06
# E (739 jumps) = -4.392E-04, change = -1.233E-06
# E (740 jumps) = -4.405E-04, change = -1.243E-06
# E (741 jumps) = -4.417E-04, change = -1.253E-06
# E (742 jumps) = -4.430E-04, change = -1.263E-06
# E (743 jumps) = -4.443E-04, change = -1.273E-06
# E (744 jumps) = -4.456E-04, change = -1.283E-06
# E (745 jumps) = -4.469E-04, change = -1.294E-06
# E (746 jumps) = -4.482E-04, change = -1.304E-06
# E (747 jumps) = -4.495E-04, change = -1.315E-06
# E (748 jumps) = -4.508E-04, change = -1.326E-06
# E (749 jumps) = -4.521E-04, change = -1.337E-06
# E (750 jumps) = -4.535E-04, change = -1.348E-06
# E (751 jumps) = -4.548E-04, change = -1.360E-06
# E (752 jumps) = -4.562E-04, change = -1.371E-06
# E (753 jumps) = -4.576E-04, change = -1.383E-06
# E (754 jumps) = -4.590E-04, change = -1.395E-06
# E (755 jumps) = -4.604E-04, change = -1.407E-06
# E (756 jumps) = -4.618E-04, change = -1.419E-06
# E (757 jumps) = -4.633E-04, change = -1.431E-06
# E (758 jumps) = -4.647E-04, change = -1.444E-06
# E (759 jumps) = -4.662E-04, change = -1.457E-06
# E (760 jumps) = -4.676E-04, change = -1.470E-06
# E (761 jumps) = -4.691E-04, change = -1.483E-06
# E (762 jumps) = -4.706E-04, change = -1.497E-06
# E (763 jumps) = -4.721E-04, change = -1.510E-06
# E (764 jumps) = -4.736E-04, change = -1.524E-06
# E (765 jumps) = -4.752E-04, change = -1.538E-06
# E (766 jumps) = -4.767E-04, change = -1.552E-06
# E (767 jumps) = -4.783E-04, change = -1.567E-06
# E (768 jumps) = -4.799E-04, change = -1.582E-06
# E (769 jumps) = -4.815E-04, change = -1.597E-06
# E (770 jumps) = -4.831E-04, change = -1.612E-06
# E (771 jumps) = -4.847E-04, change = -1.627E-06
# E (772 jumps) = -4.864E-04, change = -1.643E-06
# E (773 jumps) = -4.880E-04, change = -1.659E-06
# E (774 jumps) = -4.897E-04, change = -1.675E-06
# E (775 jumps) = -4.914E-04, change = -1.692E-06
# E (776 jumps) = -4.931E-04, change = -1.709E-06
# E (777 jumps) = -4.948E-04, change = -1.726E-06
# E (778 jumps) = -4.966E-04, change = -1.743E-06
# E (779 jumps) = -4.983E-04, change = -1.761E-06
# E (780 jumps) = -5.001E-04, change = -1.779E-06
# E (781 jumps) = -5.019E-04, change = -1.797E-06
# E (782 jumps) = -5.037E-04, change = -1.816E-06
# E (783 jumps) = -5.055E-04, change = -1.835E-06
# E (784 jumps) = -5.074E-04, change = -1.854E-06
# E (785 jumps) = -5.093E-04, change = -1.874E-06
# E (786 jumps) = -5.112E-04, change = -1.894E-06
# E (787 jumps) = -5.131E-04, change = -1.914E-06
# E (788 jumps) = -5.150E-04, change = -1.935E-06
# E (789 jumps) = -5.170E-04, change = -1.956E-06
# E (790 jumps) = -5.190E-04, change = -1.978E-06
# E (791 jumps) = -5.210E-04, change = -2.000E-06
# E (792 jumps) = -5.230E-04, change = -2.022E-06
# E (793 jumps) = -5.250E-04, change = -2.045E-06
# E (794 jumps) = -5.271E-04, change = -2.069E-06
# E (795 jumps) = -5.292E-04, change = -2.092E-06
# E (796 jumps) = -5.313E-04, change = -2.116E-06
# E (797 jumps) = -5.334E-04, change = -2.141E-06
# E (798 jumps) = -5.356E-04, change = -2.166E-06
# E (799 jumps) = -5.378E-04, change = -2.192E-06
# E (800 jumps) = -5.400E-04, change = -2.218E-06
# E (801 jumps) = -5.423E-04, change = -2.245E-06
# E (802 jumps) = -5.445E-04, change = -2.272E-06
# E (803 jumps) = -5.468E-04, change = -2.300E-06
# E (804 jumps) = -5.492E-04, change = -2.328E-06
# E (805 jumps) = -5.515E-04, change = -2.358E-06
# E (806 jumps) = -5.539E-04, change = -2.387E-06
# E (807 jumps) = -5.563E-04, change = -2.417E-06
# E (808 jumps) = -5.588E-04, change = -2.448E-06
# E (809 jumps) = -5.613E-04, change = -2.480E-06
# E (810 jumps) = -5.638E-04, change = -2.512E-06
# E (811 jumps) = -5.663E-04, change = -2.545E-06
# E (812 jumps) = -5.689E-04, change = -2.579E-06
# E (813 jumps) = -5.715E-04, change = -2.614E-06
# E (814 jumps) = -5.741E-04, change = -2.649E-06
# E (815 jumps) = -5.768E-04, change = -2.685E-06
# E (816 jumps) = -5.796E-04, change = -2.722E-06
# E (817 jumps) = -5.823E-04, change = -2.760E-06
# E (818 jumps) = -5.851E-04, change = -2.798E-06
# E (819 jumps) = -5.880E-04, change = -2.838E-06
# E (820 jumps) = -5.908E-04, change = -2.879E-06
# E (821 jumps) = -5.938E-04, change = -2.920E-06
# E (822 jumps) = -5.967E-04, change = -2.963E-06
# E (823 jumps) = -5.997E-04, change = -3.006E-06
# E (824 jumps) = -6.028E-04, change = -3.051E-06
# E (825 jumps) = -6.059E-04, change = -3.097E-06
# E (826 jumps) = -6.090E-04, change = -3.144E-06
# E (827 jumps) = -6.122E-04, change = -3.192E-06
# E (828 jumps) = -6.154E-04, change = -3.242E-06
# E (829 jumps) = -6.187E-04, change = -3.292E-06
# E (830 jumps) = -6.221E-04, change = -3.344E-06
# E (831 jumps) = -6.255E-04, change = -3.398E-06
# E (832 jumps) = -6.289E-04, change = -3.453E-06
# E (833 jumps) = -6.324E-04, change = -3.509E-06
# E (834 jumps) = -6.360E-04, change = -3.567E-06
# E (835 jumps) = -6.396E-04, change = -3.626E-06
# E (836 jumps) = -6.433E-04, change = -3.688E-06
# E (837 jumps) = -6.471E-04, change = -3.751E-06
# E (838 jumps) = -6.509E-04, change = -3.815E-06
# E (839 jumps) = -6.548E-04, change = -3.882E-06
# E (840 jumps) = -6.587E-04, change = -3.950E-06
# E (841 jumps) = -6.627E-04, change = -4.021E-06
# E (842 jumps) = -6.668E-04, change = -4.094E-06
# E (843 jumps) = -6.710E-04, change = -4.168E-06
# E (844 jumps) = -6.752E-04, change = -4.246E-06
# E (845 jumps) = -6.796E-04, change = -4.325E-06
# E (846 jumps) = -6.840E-04, change = -4.407E-06
# E (847 jumps) = -6.885E-04, change = -4.492E-06
# E (848 jumps) = -6.931E-04, change = -4.579E-06
# E (849 jumps) = -6.977E-04, change = -4.669E-06
# E (850 jumps) = -7.025E-04, change = -4.762E-06
# E (851 jumps) = -7.073E-04, change = -4.858E-06
# E (852 jumps) = -7.123E-04, change = -4.958E-06
# E (853 jumps) = -7.174E-04, change = -5.061E-06
# E (854 jumps) = -7.225E-04, change = -5.167E-06
# E (855 jumps) = -7.278E-04, change = -5.277E-06
# E (856 jumps) = -7.332E-04, change = -5.391E-06
# E (857 jumps) = -7.387E-04, change = -5.509E-06
# E (858 jumps) = -7.443E-04, change = -5.631E-06
# E (859 jumps) = -7.501E-04, change = -5.758E-06
# E (860 jumps) = -7.560E-04, change = -5.889E-06
# E (861 jumps) = -7.620E-04, change = -6.026E-06
# E (862 jumps) = -7.682E-04, change = -6.167E-06
# E (863 jumps) = -7.745E-04, change = -6.314E-06
# E (864 jumps) = -7.810E-04, change = -6.467E-06
# E (865 jumps) = -7.876E-04, change = -6.626E-06
# E (866 jumps) = -7.944E-04, change = -6.792E-06
# E (867 jumps) = -8.013E-04, change = -6.964E-06
# E (868 jumps) = -8.085E-04, change = -7.144E-06
# E (869 jumps) = -8.158E-04, change = -7.331E-06
# E (870 jumps) = -8.233E-04, change = -7.526E-06
# E (871 jumps) = -8.311E-04, change = -7.730E-06
# E (872 jumps) = -8.390E-04, change = -7.942E-06
# E (873 jumps) = -8.472E-04, change = -8.165E-06
# E (874 jumps) = -8.556E-04, change = -8.397E-06
# E (875 jumps) = -8.642E-04, change = -8.641E-06
# E (876 jumps) = -8.731E-04, change = -8.896E-06
# E (877 jumps) = -8.823E-04, change = -9.163E-06
# E (878 jumps) = -8.917E-04, change = -9.444E-06
# E (879 jumps) = -9.015E-04, change = -9.738E-06
# E (880 jumps) = -9.115E-04, change = -1.005E-05
# E (881 jumps) = -9.219E-04, change = -1.037E-05
# E (882 jumps) = -9.326E-04, change = -1.072E-05
# E (883 jumps) = -9.437E-04, change = -1.108E-05
# E (884 jumps) = -9.551E-04, change = -1.146E-05
# E (885 jumps) = -9.670E-04, change = -1.186E-05
# E (886 jumps) = -9.793E-04, change = -1.229E-05
# E (887 jumps) = -9.920E-04, change = -1.274E-05
# E (888 jumps) = -1.005E-03, change = -1.322E-05
# E (889 jumps) = -1.019E-03, change = -1.373E-05
# E (890 jumps) = -1.033E-03, change = -1.427E-05
# E (891 jumps) = -1.048E-03, change = -1.484E-05
# E (892 jumps) = -1.064E-03, change = -1.545E-05
# E (893 jumps) = -1.080E-03, change = -1.610E-05
# E (894 jumps) = -1.096E-03, change = -1.680E-05
# E (895 jumps) = -1.114E-03, change = -1.755E-05
# E (896 jumps) = -1.132E-03, change = -1.835E-05
# E (897 jumps) = -1.152E-03, change = -1.921E-05
# E (898 jumps) = -1.172E-03, change = -2.013E-05
# E (899 jumps) = -1.193E-03, change = -2.113E-05
# E (900 jumps) = -1.215E-03, change = -2.221E-05
# E (901 jumps) = -1.238E-03, change = -2.338E-05
# E (902 jumps) = -1.263E-03, change = -2.465E-05
# E (903 jumps) = -1.289E-03, change = -2.604E-05
# E (904 jumps) = -1.317E-03, change = -2.755E-05
# E (905 jumps) = -1.346E-03, change = -2.920E-05
# E (906 jumps) = -1.377E-03, change = -3.101E-05
# E (907 jumps) = -1.410E-03, change = -3.301E-05
# E (908 jumps) = -1.445E-03, change = -3.523E-05
# E (909 jumps) = -1.483E-03, change = -3.768E-05
# E (910 jumps) = -1.523E-03, change = -4.041E-05
# E (911 jumps) = -1.567E-03, change = -4.348E-05
# E (912 jumps) = -1.614E-03, change = -4.692E-05
# E (913 jumps) = -1.664E-03, change = -5.081E-05
# E (914 jumps) = -1.720E-03, change = -5.523E-05
# E (915 jumps) = -1.780E-03, change = -6.030E-05
# E (916 jumps) = -1.846E-03, change = -6.613E-05
# E (917 jumps) = -1.919E-03, change = -7.290E-05
# E (918 jumps) = -2.000E-03, change = -8.082E-05
# E (919 jumps) = -2.090E-03, change = -9.019E-05
# E (920 jumps) = -2.191E-03, change = -1.014E-04
# E (921 jumps) = -2.306E-03, change = -1.149E-04
# E (922 jumps) = -2.438E-03, change = -1.315E-04
# E (923 jumps) = -2.590E-03, change = -1.522E-04
# E (924 jumps) = -2.769E-03, change = -1.786E-04
# E (925 jumps) = -2.981E-03, change = -2.128E-04
# E (926 jumps) = -3.240E-03, change = -2.586E-04
# E (927 jumps) = -3.562E-03, change = -3.220E-04
# E (928 jumps) = -3.976E-03, change = -4.137E-04
# E (929 jumps) = -4.530E-03, change = -5.542E-04
# E (930 jumps) = -5.317E-03, change = -7.871E-04
# E (931 jumps) = -6.538E-03, change = -1.221E-03
# E (932 jumps) = -8.738E-03, change = -2.200E-03
# E (933 jumps) = -1.416E-02, change = -5.421E-03
# E (934 jumps) = -6.467E-02, change = -5.051E-02
# E (935 jumps) = -1.045E-06, change = 6.467E-02
# E (936 jumps) = -1.045E-06, change = -8.880E-13
# Converged after 936 jumps (9360 iterations)
#
# particle	x	y	z
# 1		9.298	13.834	44.956
# 2		-26266542812108.758	18414007012639.371	19564092946042.828
# 3		2.721	32.419	45.423
# 4		26266542812158.914	-18414007012562.113	-19564092946022.672
# 5		33.774	41.449	7.655
# 6		17.447	49.349	24.058
# 7		37.418	15.513	2.860

# %%
sys = System(7, System.Lennard_Jones(1, 1))
print sys.gradients
# Out:
# [[nan, nan, nan], [nan, nan, nan], [nan, nan, nan], [nan, nan, nan], [nan, nan, nan], [nan, nan, nan], [nan, nan, nan]]

# %%
test.get_active_potential([12.1, 41.4, 48.5])

# %%
test.get_active_potential(np.random.rand(3))
print test.gradients
# Out:
# [[nan, nan, nan], [nan, nan, nan], [nan, nan, nan], [nan, nan, nan], [nan, nan, nan], [nan, nan, nan], [nan, nan, nan]]

# %%
test_fun = System.Lennard_Jones(1, 1)
test_fun(test.particles[0], test.particles[1]) + 0.1
# Out:
# 0.099999999515338764
